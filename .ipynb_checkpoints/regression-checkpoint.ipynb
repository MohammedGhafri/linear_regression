# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# from sklearn.linear_model import linearRegeression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('./Fish.csv')
df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %% [markdown]
# ## Description of the data set

# %%
df.describe()
# Out:
#             Weight     Length1     Length2     Length3      Height       Width
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# min       0.000000    7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     120.000000   19.050000   21.000000   23.150000    5.944800    3.385650
# 50%     273.000000   25.200000   27.300000   29.400000    7.786000    4.248500
# 75%     650.000000   32.700000   35.500000   39.650000   12.365900    5.584500
# max    1650.000000   59.000000   63.400000   68.000000   18.957000    8.142000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
x=df['Weight'].values
y=df['Length1'].values
x=x.reshape(-1,1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,test_size=0.2,random_state=100)

# %%
x_train.shape
# Out:
# (127, 1)

# %%
x_test.shape
# Out:
# (32, 1)

# %%
plt.scatter(x_train,y_train,color='blue')
plt.xlabel('Weight')
plt.ylabel('Length')
plt.title('Fish')
plt.show()

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(x_test)

# %%
y_predict
# Out:
# array([20.20050617, 29.03196791, 42.01941164, 31.62945665, 26.17473029,
#        34.2269454 , 36.04518752, 23.57724154, 16.39258767, 20.72000392,
#        40.8505417 , 16.87572058, 34.74644315, 42.01941164, 32.92820103,
#        19.42125955, 18.9017618 , 16.04452418, 36.82443414, 22.92786935,
#        26.17473029, 40.07129508, 19.42125955, 16.29648058, 19.68100842,
#        16.56142444, 42.01941164, 30.98008447, 38.12317852, 18.64201292,
#        21.23950167, 16.30167556])

# %%
y_test
# Out:
# array([20.5, 28.7, 41.1, 29.4, 27.6, 34.5, 44.8, 24. , 11.7, 23.6, 35. ,
#        12.5, 32. , 33.5, 36.5, 20. , 19.1, 19. , 33.7, 25.4, 29.5, 36.2,
#        19.3, 10.4, 21. , 13.8, 39.8, 31.3, 32.8, 16.2, 30. , 11.3])

# %%
new_weight=np.array([500]).reshape(-1,1)

# %%
new_weight
# Out:
# array([[500]])

# %%
model.predict(new_weight)
# Out:
# array([29.03196791])

# %%
model.score(x_train,y_train)*100
# Out:
# 84.22045186321249

# %%
model.score(x_test,y_test)*100
# Out:
# 81.860794486982

# %%
# plt.scatter(x_train,y_train,color='blue')
# plt.plot(x_test,y_predict,color='red')
# plt.xlabel('Weight')
# plt.ylabel('Length')
# plt.title('Fish')
# plt.show()

# %%
import seaborn as sns

# %%
sns.set()
plt.figure(figsize=(25,5),dpi=300)
sns.regplot(x='Weight',y='Length1', data=df)
# sns.regplot(x='YearsExperience', y='Salary', data=salary)
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Length1'>

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,test_size=0.2,random_state=50)
model=LinearRegression()
model.fit(x_train,y_train)
y_predict=model.predict(x_test)

# %%
y_predict
# Out:
# array([16.60291576, 22.13509886, 16.79228761, 16.67361458, 16.76198811,
#        19.4838929 , 16.95135997, 34.12864964, 29.07873353, 34.75988916,
#        18.97890129, 34.12864964, 21.20086438, 41.70352382, 21.50385935,
#        19.2313971 , 18.22141387, 40.44104479, 33.62365803, 24.18031489,
#        16.70138912, 30.97245207, 18.65065674, 16.45394323, 24.02881741,
#        24.02881741, 26.30127966, 17.46392645, 31.60369159, 42.08226753,
#        18.60015758, 17.26192981])

# %%
plt.scatter(x_train,y_train,color='blue')
plt.plot(x_test,y_predict,color='red')
plt.xlabel('Weight')
plt.ylabel('Length')
plt.title('Fish')
plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,test_size=0.2,random_state=101)
model=LinearRegression()
model.fit(x_train,y_train)
y_predict=model.predict(x_test)

# %%
plt.scatter(x_train,y_train,color='blue')
plt.plot(x_test,y_predict,color='red')
plt.xlabel('Weight')
plt.ylabel('Length')
plt.title('Fish')
plt.show()
